# %%
# %cd ../../
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/valldabo/Documents/Hobby/PythonProjects/orderbookrl

# %% [markdown]
# # First try
#
# Reward is:
#
#
# $ cap_t = cash_t + possession_t*ask_t $
#
# $ r_t = (cap_t - cap_{t-1})/cap_t $

# %%
from orderbookrl.evaluate.collect_data import load_env_agent, run_through_all_data
import pandas as pd
# %matplotlib inline

# %%
# !pwd
# Out:
# /home/valldabo/Documents/Hobby/PythonProjects/orderbookrl

# %%
import ray

ray.init()

agent_id = 'PPO'
path = 'logs/marketorderenv/ppo-long-run/PPO_MarketOrderEnv-v0_5_2019-05-22_13-16-19dsz7zpjg/checkpoint_35/'
checkpoint = 35

env, agent = load_env_agent(agent_id, path, checkpoint)
result, trades, states, actions, rewards, quotes = run_through_all_data(env, agent)
# Out:
# Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-30_14-01-42_12702/logs.
# Waiting for redis server at 127.0.0.1:25182 to respond...
# Waiting for redis server at 127.0.0.1:35328 to respond...
# Starting the Plasma object store with 13.460106444000001 GB memory using /dev/shm.
#
# ======================================================================
# View the web UI at http://localhost:8889/notebooks/ray_ui.ipynb?token=4601a8b49ab68166fa76da8274e4e9b37239ab42e89a0478
# ======================================================================
#
# 2019-05-30 14:01:43,248	INFO catalog.py:291 -- Using custom preprocessor mv
# Created LogSyncer for /home/valldabo/ray_results/PPO_MarketOrderEnv-v0_2019-05-30_14-01-439vhpl3wo -> None
# 2019-05-30 14:01:43,266	WARNING ppo.py:118 -- By default, observations will be normalized with MeanStdFilter
# 2019-05-30 14:01:43,269	INFO catalog.py:291 -- Using custom preprocessor mv
# logs/marketorderenv/ppo-long-run/PPO_MarketOrderEnv-v0_5_2019-05-22_13-16-19dsz7zpjg/
# <class 'orderbookrl.preprocessing.phi.MarketVariables'>
# True
# <class 'orderbookmdp.rl.market_order_envs.MarketOrderEnv'>
# <class 'orderbookrl.preprocessing.phi.MarketVariables'>
# /home/valldabo/miniconda3/envs/orderbookrl/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning:
#
# Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#
# /home/valldabo/miniconda3/envs/orderbookrl/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/pandas_compat.py:752: FutureWarning:
#
# .labels was deprecated in version 0.24.0. Use .codes instead.
#
# /home/valldabo/miniconda3/envs/orderbookrl/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/pandas_compat.py:752: FutureWarning:
#
# .labels was deprecated in version 0.24.0. Use .codes instead.
# 2018-03-24 14:45:07.368000+00:00 1.0098458955609824
# 2018-03-24 21:21:56.563000+00:00 0.9877042786483989
# 2018-03-25 02:43:53.251000+00:00 0.9695271920159799
# 2018-03-25 10:40:40.203000+00:00 0.9629103981851198
# 2018-03-25 16:05:10.693000+00:00 0.9661299392720591
# 2018-03-25 22:20:47.777000+00:00 0.978099270441087
# 2018-03-26 02:59:00.489000+00:00 0.9598717629608453
# 2018-03-26 10:26:32.310000+00:00 0.9590508405065901
# 2018-03-26 14:09:16.409000+00:00 0.9435962920252389
# 2018-03-26 18:44:58.821000+00:00 0.935611038007165
# 2018-05-20 07:07:38.291000+00:00 0.004219509221728673
# 2018-05-20 16:08:26.950000+00:00 0.004140299944467546
# 2018-05-20 23:41:19.344000+00:00 0.004029296893486178
# 2018-05-21 07:25:57.392000+00:00 0.003997731089263429
# 2018-05-21 14:25:41.968000+00:00 0.0039112145208648865
# 2018-05-21 21:31:47.364000+00:00 0.003867210483863798
# 2018-05-22 01:59:48.161000+00:00 0.0037933896967685763
# 2018-05-22 06:08:26.909000+00:00 0.003696148212669979
# 2018-05-22 11:22:34.020000+00:00 0.0035858523584121585
# 2018-05-22 17:49:19.718000+00:00 0.003550476389043807
# 2018-05-22 23:07:50.696000+00:00 0.0035316396506290147
# 2018-05-23 16:36:32.295000+00:00 0.003496966762995884
# 2018-05-24 15:29:55.353000+00:00 0.003156056043301318
# 2018-05-25 20:51:10.705000+00:00 0.002818739664400346
# 2018-05-28 02:30:24.927000+00:00 0.002358897010942098
# 2018-05-29 22:28:44.201000+00:00 0.0009689515826306137
# 2018-06-01 01:03:32.091000+00:00 0.0008443922889960755
# 2018-06-08 21:38:27.702000+00:00 0.0005005145637792753

# %%
actions.columns = ['BUY=0_SELL=1_HOLD=2']
result.join(actions).plot(subplots=True, figsize=(15,10));

# %%
n_cols = 3
layout = (n_cols, 1+ int( (1+states.shape[1])/n_cols))
states.columns = ['ofi', 'vol_mb', 'macd', 'mid_std', 'possession']
states.plot(subplots=True, figsize=(15,10), layout=layout);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-136155492743> in <module>
#       1 n_cols = 3
#       2 layout = (n_cols, 1+ int( (1+states.shape[1])/n_cols))
# ----> 3 states.columns = ['ofi', 'vol_mb', 'macd', 'mid_std', 'possession']
#       4 states.plot(subplots=True, figsize=(15,10), layout=layout);
#
# ~/miniconda3/envs/orderbookrl/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5068         try:
#    5069             object.__getattribute__(self, name)
# -> 5070             return object.__setattr__(self, name, value)
#    5071         except AttributeError:
#    5072             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/miniconda3/envs/orderbookrl/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     627
#     628     def _set_axis(self, axis, labels):
# --> 629         self._data.set_axis(axis, labels)
#     630         self._clear_item_cache()
#     631
#
# ~/miniconda3/envs/orderbookrl/lib/python3.6/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 5 elements

# %%
mid = (quotes['ask'] + quotes['bid'])/2
mid.name = 'mid'
temp = mid.to_frame().join(result.possession)
temp = temp.join(result.capital/result.capital[0])
temp.plot(subplots=True, figsize=(10,10));

# %%
port_returns = result.capital.pct_change().iloc[1:]
port_cum_ret = (1+ port_returns).cumprod()
port_cum_ret.name = 'portfolio'
cum_returns = (1 + mid.pct_change().iloc[1:]).cumprod()
cum_returns.name = 'bitcoin'
temp = pd.concat([port_cum_ret, cum_returns], axis=1)
temp.plot(figsize=(10,10));

# %%
temp = mid.to_frame().join(result.possession)
temp.plot(secondary_y='possession', figsize=(15, 5));

# %% [markdown]
# # Comment
#
# The agent pushes down its capital buy constantly buying and selling and loosing on the spread. It is easier to increase percentage of capital with a lower capital.
